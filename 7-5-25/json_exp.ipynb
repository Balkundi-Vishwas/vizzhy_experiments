# %%
import json
path = r"c:\Users\Vishwas\Downloads\tbl_customer_cgm_data_202503101915.json"
def load_json(path):
    with open(path,'r') as f:
        data = json.load(f)
    # Flatten or join fields as needed:
    return " ".join(str(v) for v in data.values())

# %%
data = load_json(r"c:\Users\Vishwas\Downloads\tbl_customer_cgm_data_202503101915.json")

# %%
print(type(data))
# Out:
# <class 'str'>

# %%
from bs4 import BeautifulSoup # html
def load_html(path):
    with open(path, 'r', encoding='utf-8') as f:
        soup = BeautifulSoup(f, 'html.parser')
    return soup.get_text()

# %%
html_data = load_html(r"C:\Users\Vishwas\Downloads\html_vishnu Whole Metabolome Plasma Report 3.html")

# %%
print(html_data)
# Out:
# Dear patient,
# Congratulations on reaching a pivotal moment in your personal health journey. The comprehensive insights in your unique report are designed to empower both you and your healthcare provider, paving the way for informed decisions about your well-being.
# Your plasma analysis is grounded in the latest advancements in medical science. Plasma plays a crucial role in maintaining the balance and functionality of various bodily systems. These insights will help you understand how different components of plasma, such as electrolytes, hormones, proteins, and nutrients, impact your overall health and physiological functions.
# For additional information and support resources, please visit our website. It’s filled with useful content that can help you deepen your understanding of how lipids affect your body.
# ...

# %%
from langchain.document_loaders import DirectoryLoader
from langchain_community.document_loaders.html import UnstructuredHTMLLoader

loader = DirectoryLoader(
    r"C:\Users\Vishwas\Documents\projects\data\html_files",              # path to your folder
    glob="**/*.html",         # pattern to match HTML files
    loader_cls=UnstructuredHTMLLoader,
    loader_kwargs={"mode": "single"},
)

documents = loader.load()
print(f"Loaded {len(documents)} documents")
# Out:
# Error loading file C:\Users\Vishwas\Documents\projects\data\html_files\html_vishnu_whole_lipidome_report_2_(1).html
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\Vishwas\miniconda3\envs\mcondaenv\Lib\site-packages\langchain_community\document_loaders\unstructured.py:59, in UnstructuredBaseLoader.__init__(self, mode, post_processors, **unstructured_kwargs)
#      58 try:
# ---> 59     import unstructured  # noqa:F401
#      60 except ImportError:
#
# ModuleNotFoundError: No module named 'unstructured'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 11
#       2 from langchain_community.document_loaders.html import UnstructuredHTMLLoader
#       4 loader = DirectoryLoader(
# ...

# %%
len("An example of the latter is one variant that predisposes you to straight hair and one that predisposes you to curly hair. Information published on individual variants often do not take into account the effects of variants in various combinations, but only their independent effects. myGenome includes the following lifestyle trait categories.")
# Out:
# 342

# %%
len("""Human: <think>
You are an intelligent health assistant. Your task is to analyze and interpret patient health and multi-omics data.Use only the information provided in the context to answer. Provide clear, concise, and fact-based responses.Cite each statement with its source document in the format “[doc1]”. If the answer cannot be derived confidently from the data, say: “I’m not confident.” Context:
d	medications.	Certain	genetic	variations	(or	changes) may	influence	how	we	metabolize	or	react	to	certain	drugs.	In	some	cases,	these	genetic	variations	could	amplify	the beneficial	effect	of	a	drug	or	on	the	other	hand,	decrease	its	effectiveness.	In	extreme	situations,	individuals	who	carry certain	genetic	variations	may	experience	adverse	drug	reactions.	This	knowledge	may	help	your	physician	to	tailor medication	to	your	personal	genetic	map,	by	minimizing	adverse	reactions	and	maximizing	the	positive	outcome.NOTE: Never	change	your	drug	regimen	except	under	the	guidance	of	a	clinical	pharmacologist	or	other	authorized	healthcare provider.	See	technical	note	for	important	limitations	of	the	test.

Immediate	Attention	Needed	(Major	Gene-Drug	Interaction)

Toxicity

Toxicity

Toxicity

Toxicity

Toxicity

Drug	Name Genotype Evidence Medication	used	for

Fluorouracil A/A>A/G

1A

Neoplasms

Implication Both	variants	of	rs1801265	are	assigned normal	function	by	CPIC.	Patients	with	the

genotype	and	Hepatitis	C	may	have	decreased	trough	concentrations	of	telaprevir	compared	to patients	with	the	TT

genotype.	Other	factors	may	affect	trough	concentrations	of	telaprevir.

Patients	with	the	CT	genotype	and	beta-thalassemia	may	have	decreased	metabolism	of	deferasirox	as	compared	to patients	with	the

CC	genotype.	Other	genetic	and	clinical	factors	may	also	influence	deferasirox	metabolism.

Patients	with	acute	lymphoblastic	leukemia	and	the	rs1051296	AC

genotype	may	have	decreased	concentrations	of	methotrexate	as	compared	to	patients	with	the	AA	genotype.	This annotation	only

covers	the	pharmacokinetic	relationship	between	rs1051296	and	methotrexate	and	does	not	include	evidence	about clinical	outcomes.

Other	genetic	and	clinical	factors	may	also	influence	methotrexate	concentrations.

Other

Drug	Name Genotype Evidence

Medication used	for

Implication

Heroin

A/A>G/G 3

Fluorouracil

T/T>C/C 3

Atazanavir

C/C>T/T 3

Acetaminophen T/T>C/C 3

Acetaminophen G/G>C/C

arry certain	genetic	variations	may	experience	adverse	drug	reactions.	This	knowledge	may	help	your	physician	to	tailor

medication	to	your	personal	genetic	map,	by	minimizing	adverse	reactions	and	maximizing	the	positive	outcome.NOTE: Never	change	your	drug	regimen	except	under	the	guidance	of	a	clinical	pharmacologist	or	other	authorized	healthcare provider.	See	technical	note	for	important	limitations	of	the	test.

Immediate	Attention	Needed	(Major	Gene-Drug	Interaction)

Toxicity

Toxicity

Toxicity

Toxicity

Toxicity

Drug	Name Genotype Evidence Medication	used	for

Fluorouracil A/A>A/G

1A

Neoplasms

Implication Both	variants	of	rs1801265	are	assigned normal	function	by	CPIC.	Patients	with	the	AG genotype	and	cancer	who	are	treated	with fluorouracil,	a	fluoropyrimidine-based chemotherapy,	may	not	have	altered	risk	of drug	toxicity	as	compared	to	patients	with	the AA	or	GG	genotype.	However,	conflicting evidence	has	been	reported.	Other	genetic	and clinical	factors	may	also	infl

Question: summarize the pharmacogenetic toxicity profiles of patient  in the context of gene-drug interactions
Answer:
<END> 

Okay, so I need to summarize the pharmacogenetic toxicity profiles of a patient based on the provided context. Let me start by reading through the context carefully to understand what information is available.

The context mentions that certain genetic variations can influence how the body metabolizes or reacts to certain drugs. This can either amplify the drug's effect, reduce its effectiveness, or in extreme cases, cause adverse reactions. The knowledge can help tailor medication based on the patient's genetic makeup to minimize adverse reactions and maximize positive outcomes. However, it's important to note that this should only be done under the guidance of a clinical pharmacologist.

Looking at the table provided, there are several drugs listed with their corresponding genotypes and the evidence supporting the interactions. Each entry includes the drug name, genotype, evidence, and the medication used for. The implications section also provides some details about how these genetic variations affect the drugs.

Let me break it down:

1. **Fluorouracil**: The genotype mentioned is A/A>A/G with a level of evidence 1A. It's used for neoplasms. The implication is that both variants of rs1801265 are assigned normal function by CPIC. Patients with the AG genotype and cancer treated with fluorouracil may not have altered risk of drug toxicity compared to AA or GG genotypes. However, conflicting evidence has been reported, and other factors may also influence toxicity.

2. **Telaprevir**: Patients with the TT genotype may have higher trough concentrations, which could be beneficial or require dosage adjustments. Those with the CT genotype and beta-thalassemia may metabolize deferasirox differently.

3. **Deferasirox**: Patients with the CT genotype have decreased metabolism compared to CC, affecting the drug's effectiveness.

4. **Methotrexate**: AC genotype in acute lymphoblastic leukemia is linked to lower concentrations compared to AA. This affects pharmacokinetics but not necessarily clinical outcomes.

5. **Heroin**: A/A>G/G genotype may affect metabolism or response, but specifics aren't provided.

6. **Atazanavir**: C/C>T/T genotype affects trough concentrations, requiring monitoring.

7. **Acetaminophen**: T/T>C/C and G/G>C/C genotypes affect metabolism, but the specifics vary.

Now, the question is to summarize the pharmacogenetic toxicity profiles. I need to highlight the key points for each drug, noting how the genotypes affect toxicity, effectiveness, or required dosage adjustments.

For each
""")
# Out:
# 6080
