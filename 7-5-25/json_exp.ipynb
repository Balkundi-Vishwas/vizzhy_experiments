# %%
import json
path = r"c:\Users\Vishwas\Downloads\tbl_customer_cgm_data_202503101915.json"
def load_json(path):
    with open(path,'r') as f:
        data = json.load(f)
    # Flatten or join fields as needed:
    return " ".join(str(v) for v in data.values())

# %%
data = load_json(r"c:\Users\Vishwas\Downloads\tbl_customer_cgm_data_202503101915.json")

# %%
print(type(data))
# Out:
# <class 'str'>

# %%
from bs4 import BeautifulSoup # html
def load_html(path):
    with open(path, 'r', encoding='utf-8') as f:
        soup = BeautifulSoup(f, 'html.parser')
    return soup.get_text()

# %%
html_data = load_html(r"C:\Users\Vishwas\Downloads\html_vishnu whole lipidome report 2.html")

# %%
print(html_data)
# Out:
# Name
# Sex
# Age
# Report ID Date of Report Customer ID
#
#
#
# +90 216 570 20 00
# info@szalongevity.com
#
# www.szalongevity.com
# çerenköy Kerem Aydnlar Kampüsü, Kaytda Cd. No:32, 34752 Ataehir/Istanbul
#
# Dear patient,
# Congratulations on reaching a pivotal moment in your personal health journey. The comprehensive insights in your unique report are designed to empower both you and your healthcare provider, paving the way for informed decisions about your well-being.
# Your lipid profile analysis is grounded in the latest advancements in medical science. Lipids play crucial roles in maintaining the health and functionality of various organ systems. These insights will help you understand how different types of lipids, such as carnitines, fatty acids, glycerolipids, and others, impact your overall health.
# ...
